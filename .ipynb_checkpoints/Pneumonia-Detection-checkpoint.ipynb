# %% [markdown]
# ### Extracting Dataset from archive.zip
# Extracts all the contents (like images, folders) into the current working directory.

# %%
import zipfile
z = zipfile.ZipFile("archive.zip")
z.extractall()

# %% [markdown]
# #### Installing Required Libraries

# %%
# !pip install numpy pandas opencv-python scikit-image matplotlib seaborn
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### Before Resizing (Original Images)

# %%
pneumonia = os.listdir("chest_xray/train/PNEUMONIA")
pneumonia_dir = "chest_xray/train/PNEUMONIA"
normal = os.listdir("chest_xray/train/NORMAL")
normal_dir = "chest_xray/train/NORMAL"

# %%
import random

plt.figure(figsize=(20,10))

sample_images = random.sample(pneumonia, 6)

for i in range(3):
    plt.subplot(3, 3, i + 1)
    img = plt.imread(os.path.join(pneumonia_dir, sample_images[i]))
    plt.imshow(img, cmap='gray')
    plt.axis("off")
    plt.title("Pneumonia X-ray")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,10))

for i in range(3):
    plt.subplot(3,3, i+1)
    img = plt.imread(os.path.join(normal_dir, normal[i]))
    plt.imshow(img, cmap='gray')
    plt.axis("off")
    plt.title("Normal X-ray")
plt.tight_layout()
plt.show()

# %% [markdown]
# ####  Importing Libraries

# %%
import os, shutil
import random
import numpy as np
import pandas as pd
import cv2
import skimage
import matplotlib.pyplot as plt
import skimage.segmentation
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# ####  Loading and Preprocessing X-ray Images

# %%
import os
import cv2
import numpy as np

labels = ['PNEUMONIA', 'NORMAL']
img_size = 128

def get_data(data_dir):
    images = []  # List to store images
    labels_list = []  # List to store labels
    valid_extensions = (".jpg", ".jpeg", ".png", ".bmp")  # Only allow image files
    
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        
        for img in os.listdir(path):
            img_path = os.path.join(path, img)

            # Skip non-image files (like .DS_Store)
            if not img.lower().endswith(valid_extensions):
                print(f"Skipping non-image file: {img_path}")
                continue
            
            try:
                img_arr = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

                if img_arr is None:
                    print(f"Warning: Unable to read image {img_path}")
                    continue  # Skip this image
                
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                images.append(resized_arr)
                labels_list.append(class_num)
            except Exception as e:
                print(f"Error processing {img}: {e}")
    
    images = np.array(images, dtype=np.float32)  # Convert to numpy array with float32
    labels_list = np.array(labels_list, dtype=np.int32)  # Convert labels to numpy array with int32
    images = images / 255.0  # Normalize image pixel values between 0 and 1
    return images, labels_list

# Load datasets
train_images, train_labels = get_data("chest_xray/chest_xray/train")
test_images, test_labels = get_data("chest_xray/chest_xray/test")
val_images, val_labels = get_data("chest_xray/chest_xray/val")

# Check shapes
print(f"Train images shape: {train_images.shape}")
print(f"Train labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")
print(f"Validation images shape: {val_images.shape}")
print(f"Validation labels shape: {val_labels.shape}")
# Out:
# Skipping non-image file: chest_xray/chest_xray/train\PNEUMONIA\.DS_Store
# Skipping non-image file: chest_xray/chest_xray/train\NORMAL\.DS_Store
# Skipping non-image file: chest_xray/chest_xray/val\PNEUMONIA\.DS_Store
# Skipping non-image file: chest_xray/chest_xray/val\NORMAL\.DS_Store
# Train images shape: (5216, 128, 128)
# Train labels shape: (5216,)
# Test images shape: (624, 128, 128)
# Test labels shape: (624,)
# Validation images shape: (16, 128, 128)
# Validation labels shape: (16,)

# %%
import os
import cv2
import numpy as np

labels = ['PNEUMONIA', 'NORMAL']
img_size = 128

def get_data(data_dir):
    images = []  # List to store images
    labels_list = []  # List to store labels
    valid_extensions = (".jpg", ".jpeg", ".png", ".bmp")  # Only allow image files
    
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        
        for img in os.listdir(path):
            img_path = os.path.join(path, img)

            # Skip non-image files (like .DS_Store)
            if not img.lower().endswith(valid_extensions):
                print(f"Skipping non-image file: {img_path}")
                continue
            
            try:
                img_arr = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

                if img_arr is None:
                    print(f"Warning: Unable to read image {img_path}")
                    continue  # Skip this image
                
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                images.append(resized_arr)
                labels_list.append(class_num)
            except Exception as e:
                print(f"Error processing {img}: {e}")
    
    images = np.array(images, dtype=np.float32)  # Convert to numpy array with float32
    labels_list = np.array(labels_list, dtype=np.int32)  # Convert labels to numpy array with int32
    images = images / 255.0  # Normalize image pixel values between 0 and 1
    return images, labels_list

# Load datasets
train_images, train_labels = get_data("chest_xray/train")
test_images, test_labels = get_data("chest_xray/test")
val_images, val_labels = get_data("chest_xray/val")

# Check shapes
print(f"Train images shape: {train_images.shape}")
print(f"Train labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")
print(f"Validation images shape: {val_images.shape}")
print(f"Validation labels shape: {val_labels.shape}")
# Out:
# Train images shape: (5216, 128, 128)
# Train labels shape: (5216,)
# Test images shape: (624, 128, 128)
# Test labels shape: (624,)
# Validation images shape: (16, 128, 128)
# Validation labels shape: (16,)

# %% [markdown]
# #### After Resizing

# %%
import matplotlib.pyplot as plt

# Find indices of NORMAL and PNEUMONIA images separately
normal_indices = np.where(train_labels == labels.index('NORMAL'))[0]
pneumonia_indices = np.where(train_labels == labels.index('PNEUMONIA'))[0]

# Number of images to show
num_images = 3

# Let's pick 3 NORMAL and 3 PNEUMONIA images
selected_indices = list(normal_indices[:3]) + list(pneumonia_indices[:3])

plt.figure(figsize=(10,10))

for i, idx in enumerate(selected_indices):
    plt.subplot(3, 3, i+1)
    plt.imshow(train_images[idx], cmap='gray')
    label = labels[train_labels[idx]]
    plt.title(label)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import os
print(os.listdir("chest_xray"))  # or os.listdir("chest_xray/chest_xray")
# Out:
# ['chest_xray', 'test', 'train', 'val', '__MACOSX']

# %% [markdown]
# #### Visualizing Class Distribution in Training Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Map numeric labels to class names
class_names = ['PNEUMONIA', 'NORMAL']  # correct class order
listx = [class_names[label] for label in train_labels]

# Create a DataFrame
df = pd.DataFrame({'Class': listx})

# Plot the countplot
plt.figure(figsize=(6,6))
sns.countplot(data=df, x='Class', hue='Class', palette='Set2', legend=False)

# Adding counts on top
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', 
                       (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', 
                       xytext=(0, 10), 
                       textcoords='offset points')

plt.title("Distribution of Classes in Training Data")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# %%
# !pip install tensorflow
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### Necessary imports for model preparation

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D,Dropout
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.optimizers import SGD, RMSprop, Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# #### data augmentation and image preprocessing

# %%
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=40,
    shear_range=0.2,
    width_shift_range=0.4,
    height_shift_range=0.4,
    fill_mode="nearest"
)

valid_datagen = ImageDataGenerator(rescale=1. / 255)
test_datagen = ImageDataGenerator(rescale=1. / 255)

# %% [markdown]
# ####  Training Data Generator

# %%
train_generator = train_datagen.flow_from_directory("chest_xray/train",
                                 batch_size = 32,
                                 target_size=(128,128),
                                 class_mode = 'categorical',
                                 shuffle=True,
                                 seed = 42,
                                 color_mode = 'rgb')
valid_generator = valid_datagen.flow_from_directory("chest_xray/val",
                                 batch_size = 32,
                                 target_size=(128,128),
                                 class_mode = 'categorical',
                                 shuffle=True,
                                 seed = 42,
                                 color_mode = 'rgb')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.

# %%
class_labels = train_generator.class_indices

# %%
class_labels
# Out:
# {'NORMAL': 0, 'PNEUMONIA': 1}

# %%
class_name = {value:key for (key, value) in class_labels.items()}

# %%
class_name
# Out:
# {0: 'NORMAL', 1: 'PNEUMONIA'}

# %%
base_model = VGG19(input_shape = (128,128,3),
                     include_top = False,
                     weights = 'imagenet')
for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
flat = Flatten()(x)


class_1 = Dense(4608, activation = 'relu')(flat)
dropout = Dropout(0.2)(class_1)
class_2 = Dense(1152, activation = 'relu')(dropout)
output = Dense(2, activation = 'softmax')(class_2)

model_01 = Model(base_model.inputs, output)
model_01.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 128, 128, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 128, 128, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 64, 64, 64)          │               0 │
# ...

# %%
filepath = "model.h5"
es = EarlyStopping(monitor="val_loss", verbose=1, mode="min", patience=4)
cp=ModelCheckpoint(filepath, monitor="val_loss", save_best_only=True, save_weights_only=False,mode="auto", save_freq="epoch")
lrr = ReduceLROnPlateau(monitor="val_accuracy", patience=3, verbose=1, factor=0.5, min_lr=0.0001)

sgd = SGD(learning_rate=0.0001, decay = 1e-6, momentum=0.9, nesterov = True)

model_01.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=['accuracy'])

# %%
history_01 = model_01.fit(
            train_generator,
            steps_per_epoch=50,
            epochs=4, 
            callbacks=[es, cp, lrr],
            validation_data=valid_generator)
# Out:
# Epoch 1/4
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7335 - loss: 0.5294
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 348s 7s/step - accuracy: 0.7338 - loss: 0.5287 - val_accuracy: 0.5625 - val_loss: 0.6150 - learning_rate: 1.0000e-04
# Epoch 2/4
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 363s 7s/step - accuracy: 0.7737 - loss: 0.4695 - val_accuracy: 0.5625 - val_loss: 0.6178 - learning_rate: 1.0000e-04
# Epoch 3/4
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7826 - loss: 0.4360
# ...

# %%
import matplotlib.pyplot as plt

# Accuracy graph
plt.plot(history_01.history['accuracy'], label='Training Accuracy')
plt.plot(history_01.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Loss graph
plt.plot(history_01.history['loss'], label='Training Loss')
plt.plot(history_01.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
if not os.path.isdir('model_weights/'):
    os.mkdir("model_weights/")
model_01.save(filepath = "model_weights/vgg19_model_01.h5", overwrite=True)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test_generator = test_datagen.flow_from_directory("chest_xray/test",
                                 batch_size = 32,
                                 target_size=(128,128),
                                 class_mode = 'categorical',
                                 shuffle=False,
                                 seed = 42,
                                 color_mode = 'rgb')
# Out:
# Found 624 images belonging to 2 classes.

# %%
loss, accuracy = model_01.evaluate(test_generator, steps=len(test_generator))
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - accuracy: 0.3039 - loss: 0.8291
# Test Loss: 0.5847
# Test Accuracy: 0.6266

# %%
model_01.load_weights("model_weights/vgg19_model_01.h5")

vgg_val_eval_01 = model_01.evaluate(valid_generator)
vgg_test_eval_01 = model_01.evaluate(test_generator)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5000 - loss: 0.7191
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 75s 4s/step - accuracy: 0.3039 - loss: 0.8291

# %%
print(f"Validation Loss: {vgg_val_eval_01[0]}")
print(f"Validation Accuarcy: {vgg_val_eval_01[1]}")
print(f"Test Loss: {vgg_test_eval_01[0]}")
print(f"Test Accuarcy: {vgg_test_eval_01[1]}")
# Out:
# Validation Loss: 0.7190834283828735
# Validation Accuarcy: 0.5
# Test Loss: 0.5847335457801819
# Test Accuarcy: 0.6266025900840759

# %%
# Get one batch of images and labels from the test set
images, labels = next(iter(test_generator))

# Predict on the batch
predictions = model_01.predict(images)

# Get class names (you already have this from earlier)
class_name = {0: 'NORMAL', 1: 'PNEUMONIA'}  # example, adjust if needed!

# Show the first 5 images
for i in range(5):
    plt.figure(figsize=(4,4))
    plt.imshow(images[i])
    plt.axis('off')

    # Get predicted class
    pred_class = np.argmax(predictions[i])
    real_class = np.argmax(labels[i])

    plt.title(f"Real: {class_name[real_class]}\nPredicted: {class_name[pred_class]}")
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
base_model = VGG19(include_top=False, input_shape=(128,128,3))
base_model_layer_names = [layer.name for layer in base_model.layers]

x = base_model.output
flat = Flatten()(x)


class_1 = Dense(4608, activation = 'relu')(flat)
dropout = Dropout(0.2)(class_1)
class_2 = Dense(1152, activation = 'relu')(dropout)
output = Dense(2, activation = 'softmax')(class_2)

model_02 = Model(base_model.inputs, output)
model_02.load_weights("model_weights/vgg19_model_01.h5")

set_trainable = False
for layer in base_model.layers:
    if layer.name in ['block5_conv3', 'block5_conv4']:
        set_trainable = True
    layer.trainable = set_trainable

print(model_02.summary())
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 128, 128, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 128, 128, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 64, 64, 64)          │               0 │
# ...

# %%
base_model_layer_names
# Out:
# ['input_layer_3',
#  'block1_conv1',
#  'block1_conv2',
#  'block1_pool',
#  'block2_conv1',
#  'block2_conv2',
#  'block2_pool',
#  'block3_conv1',
#  'block3_conv2',
#  'block3_conv3',
#  'block3_conv4',
#  'block3_pool',
#  'block4_conv1',
#  'block4_conv2',
#  'block4_conv3',
#  'block4_conv4',
#  'block4_pool',
#  'block5_conv1',
#  'block5_conv2',
#  'block5_conv3',
#  'block5_conv4',
#  'block5_pool']

# %%
sgd = SGD(learning_rate=0.0001, decay = 1e-6, momentum=0.0, nesterov = True)

model_02.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=['accuracy'])

# %% [markdown]
# #### mmmmmmmmm

# %%
test_eval = model_mobilenet.evaluate(test_generator)
print(f"Test loss: {test_eval[0]}")
print(f"Test accuracy: {test_eval[1]}")
# Out:
# C:\Users\sksir\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_757']
# Received: inputs=Tensor(shape=(32, 128, 128, 3))
#   warnings.warn(msg)
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 783ms/step - accuracy: 0.6551 - loss: 0.6710
# C:\Users\sksir\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_757']
# Received: inputs=Tensor(shape=(16, 128, 128, 3))
#   warnings.warn(msg)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 788ms/step - accuracy: 0.6657 - loss: 0.6543
# Test loss: 0.49584007263183594
# Test accuracy: 0.7660256624221802

# %%
# load weights
model_02.load_weights("model_weights/vgg19_model_01.h5")

# AFTER making layers trainable
set_trainable = False
for layer in base_model.layers:
    if layer.name in ['block5_conv3', 'block5_conv4']:
        set_trainable = True
    layer.trainable = set_trainable

# 🔥 important: compile fresh AFTER setting layer trainability
sgd = SGD(learning_rate=0.0001, decay=1e-6, momentum=0.0, nesterov=True)
model_02.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=['accuracy'])

# ✅ Now fit
history_02 = model_02.fit(
    train_generator, 
    steps_per_epoch=10,
    epochs=1, 
    callbacks=[es, cp, lrr],
    validation_data=valid_generator
)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 226s 23s/step - accuracy: 0.7649 - loss: 0.4938 - val_accuracy: 0.5000 - val_loss: 0.6863 - learning_rate: 1.0000e-04

# %%
if not os.path.isdir('model_weights/'):
    os.mkdir("model_weights/")
model_02.save(filepath = "model_weights/vgg19_model_02.h5", overwrite=True)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model_02.load_weights("model_weights/vgg19_model_02.h5")

vgg_val_eval_02 = model_02.evaluate(valid_generator)
vgg_test_eval_02 = model_02.evaluate(test_generator)

print(f"Validation Loss: {vgg_val_eval_02[0]}")
print(f"Validation Accuarcy: {vgg_val_eval_02[1]}")
print(f"Test Loss: {vgg_test_eval_02[0]}")
print(f"Test Accuarcy: {vgg_test_eval_02[1]}")
# Out:
# C:\Users\sksir\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_234']
# Received: inputs=Tensor(shape=(16, 128, 128, 3))
#   warnings.warn(msg)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5000 - loss: 0.7191
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - accuracy: 0.3039 - loss: 0.8291
# Validation Loss: 0.719083309173584
# Validation Accuarcy: 0.5
# Test Loss: 0.5847335457801819
# Test Accuarcy: 0.6266025900840759

# %%
base_model = VGG19(include_top=False, input_shape=(128,128,3))

x = base_model.output
flat = Flatten()(x)

class_1 = Dense(4608, activation = 'relu')(flat)
dropout = Dropout(0.2)(class_1)
class_2 = Dense(1152, activation = 'relu')(dropout)
output = Dense(2, activation = 'softmax')(class_2)

model_03 = Model(base_model.inputs, output)
model_03.load_weights("model_weights/vgg19_model_01.h5")

print(model_03.summary())
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)           │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 128, 128, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 128, 128, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 64, 64, 64)          │               0 │
# ...

# %%
sgd = SGD(learning_rate=0.0001, decay = 1e-6, momentum=0.0, nesterov = True)

model_03.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=['accuracy'])

# %%
history_03 = model_02.fit(train_generator, 
            steps_per_epoch=100,
            epochs=1, 
            callbacks=[es, cp, lrr],
            validation_data=valid_generator)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1681s 17s/step - accuracy: 0.7621 - loss: 0.4836 - val_accuracy: 0.5625 - val_loss: 0.6325 - learning_rate: 1.0000e-04

# %%
if not os.path.isdir('model_weights/'):
    os.mkdir("model_weights/")
model_02.save(filepath = "model_weights/vgg_unfrozen.h5", overwrite=True)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Step 1: Imports
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG19
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# Step 2: Data Directories
train_path = 'chest_xray/train'
val_path = 'chest_xray/val'
test_path = 'chest_xray/test'

# Step 3: Data Augmentation + Normalization
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_gen = train_datagen.flow_from_directory(
    train_path, 
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical'
)

val_gen = val_datagen.flow_from_directory(
    val_path, 
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.

# %%
# Optional: print class indices to confirm mapping
print("Class indices:", train_gen.class_indices)
# Out:
# Class indices: {'NORMAL': 0, 'PNEUMONIA': 1}

# %%
# Step 4: Build the Model
base_model = VGG19(include_top=False, weights='imagenet', input_shape=(128,128,3))
for layer in base_model.layers:
    layer.trainable = True

x = Flatten()(base_model.output)
x = Dense(4608, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(1152, activation='relu')(x)
output = Dense(2, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# %%
# Step 5: Compile Model
model.compile(optimizer=Adam(learning_rate=1e-4), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Step 6: Train Model
checkpoint = ModelCheckpoint('vgg_unfrozen.h5', save_best_only=True, monitor='val_accuracy', mode='max')
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=10,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - accuracy: 0.7517 - loss: 0.5464
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 2538s 16s/step - accuracy: 0.7520 - loss: 0.5457 - val_accuracy: 0.6250 - val_loss: 0.9886
# Epoch 2/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 99s/step - accuracy: 0.9009 - loss: 0.2391
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ...

# %%
# Step 7: Plot Training Performance
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title("Training vs Validation Accuracy")
plt.show()

accuracy = history.history['accuracy'][-1]
# Step 8: Test Evaluation
test_gen = val_datagen.flow_from_directory(
    test_path,
    target_size=(128, 128),
    class_mode='categorical'
)

loss, acc = model.evaluate(test_gen)

print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# Found 624 images belonging to 2 classes.
# Test Accuracy: 97.18%

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Generate Predictions
test_gen = val_datagen.flow_from_directory(
    test_path,
    target_size=(128, 128),
    class_mode='categorical',
    shuffle=False  # Don't shuffle to align true labels with predictions
)

# Get model predictions
predictions = model.predict(test_gen)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_gen.classes
# Step 2: Manually Create the Confusion Matrix
num_classes = len(test_gen.class_indices)  # Number of classes
conf_matrix = np.zeros((num_classes, num_classes), dtype=int)
for true, pred in zip(true_classes, predicted_classes):
    conf_matrix[true, pred] += 1
# Step 3: Plot the Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=test_gen.class_indices.keys(), 
            yticklabels=test_gen.class_indices.keys())
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Found 624 images belonging to 2 classes.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step

# %%
pip install scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting scikit-learn
# ...
#      ---------------------------------------- 11.1/11.1 MB 3.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 301.8/301.8 kB 2.3 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

test_gen = val_datagen.flow_from_directory(
    test_path,
    target_size=(128, 128),
    class_mode='categorical',
    shuffle=False  # Important: keep shuffle=False so that the true labels align with predictions
)

predictions = model.predict(test_gen)
predicted_classes = np.argmax(predictions, axis=1)

# Get true labels from the test generator
true_classes = test_gen.classes

acuracy = accuracy_score(true_classes, predicted_classes)
precsion = precision_score(true_classes, predicted_classes, average='macro')  # Macro-average for multi-class
recal = recall_score(true_classes, predicted_classes, average='macro')  # Macro-average for multi-class
f1 = f1_score(true_classes, predicted_classes, average='macro')  # Macro-average for multi-class

print(f"Test Accuracy: {accuracy * 100:.2f}%")
print(f"Precision: {precision * 100:.2f}%")
print(f"Recall: {recall * 100:.2f}%")
print(f"F1 Score: {f1Score * 100:.2f}%")
# Out:
# Found 624 images belonging to 2 classes.
# C:\Users\sksir\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# C:\Users\sksir\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step
# Test Accuracy: 97.18%
# Precision: 96.92%
# Recall: 91.53%
# F1 Score: 94.15%
